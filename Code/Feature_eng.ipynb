# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('UNSW_NB15_training-set.csv')

# %%
df.head()
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes       rate  \
# 0   1  0.121478   tcp       -   FIN      6      4     258     172  74.087490
# 1   2  0.649902   tcp       -   FIN     14     38     734   42014  78.473372
# 2   3  1.623129   tcp       -   FIN      8     16     364   13186  14.170161
# 3   4  1.681642   tcp     ftp   FIN     12     12     628     770  13.677108
# 4   5  0.449454   tcp       -   FIN     10      6     534     268  33.373826
#
#    ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0  ...                 1               1             0           0
# 1  ...                 1               2             0           0
# 2  ...                 1               3             0           0
# 3  ...                 1               3             1           1
# 4  ...                 1              40             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  attack_cat  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175341 entries, 0 to 175340
# Data columns (total 45 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 175341 non-null  int64
#  1   dur                175341 non-null  float64
#  2   proto              175341 non-null  object
#  3   service            175341 non-null  object
#  4   state              175341 non-null  object
#  5   spkts              175341 non-null  int64
#  6   dpkts              175341 non-null  int64
#  7   sbytes             175341 non-null  int64
#  8   dbytes             175341 non-null  int64
#  9   rate               175341 non-null  float64
#  10  sttl               175341 non-null  int64
#  11  dttl               175341 non-null  int64
#  12  sload              175341 non-null  float64
#  13  dload              175341 non-null  float64
#  14  sloss              175341 non-null  int64
# ...

# %%
df = df.drop(['attack_cat'],axis = 1)

# %%
df.isnull().sum()
# Out:
# id                   0
# dur                  0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ...

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['label'].value_counts()
# Out:
# label
# 1    119341
# 0     56000
# Name: count, dtype: int64

# %%
numerical = df.select_dtypes(include = 'number')
cat = df.select_dtypes(exclude = 'number')

# %%
# dist
for i in numerical.columns:
    plt.figure()
    sns.distplot(numerical[i])
    plt.show()
# Out:
# /tmp/ipython-input-99-2691025826.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical[i])
# /tmp/ipython-input-99-2691025826.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(numerical[i])
# /tmp/ipython-input-99-2691025826.py:4: UserWarning:
#
# ...

# %%
# drop id
df = df.drop(['id'],axis = 1)

# %%
# corr
plt.figure(figsize = (20,20))
sns.heatmap(numerical.corr(),annot = True)
# Out:
# <Axes: >

# %%
corr_mat = numerical.corr()

# %%
# Getting and printing high correlated features
limit = 0.9

columns = corr_mat.columns
for i in range(corr_mat.shape[0]):
    for j in range(i+1, corr_mat.shape[0]):
        if corr_mat.iloc[i, j] >= 0.9:
            print(f"{columns[i]:20s} {columns[j]:20s} {corr_mat.iloc[i, j]}")
# Out:
# spkts                sbytes               0.9637905453658627
# spkts                sloss                0.9710686917738107
# dpkts                dbytes               0.9719070079919281
# dpkts                dloss                0.9786363765709863
# sbytes               sloss                0.9961094729148002
# dbytes               dloss                0.9965035947623478
# sinpkt               is_sm_ips_ports      0.9413189007355157
# swin                 dwin                 0.9901399299415929
# tcprtt               synack               0.9494676611067603
# tcprtt               ackdat               0.9417603738127356
# ct_srv_src           ct_dst_src_ltm       0.9671378245460094
# ct_srv_src           ct_srv_dst           0.9803230099911133
# ct_dst_ltm           ct_src_dport_ltm     0.9620518416459877
# ct_src_dport_ltm     ct_dst_sport_ltm     0.9067931558835277
# ct_dst_src_ltm       ct_srv_dst           0.9723704538697349
# is_ftp_login         ct_ftp_cmd           1.0

# %%
todrop = ['sloss', 'dloss', 'dwin', 'ct_src_dport_ltm', 'ct_dst_src_ltm', 'ct_ftp_cmd', 'ct_srv_dst']
df.drop(columns=todrop, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175341 entries, 0 to 175340
# Data columns (total 36 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dur                175341 non-null  float64
#  1   proto              175341 non-null  object
#  2   service            175341 non-null  object
#  3   state              175341 non-null  object
#  4   spkts              175341 non-null  int64
#  5   dpkts              175341 non-null  int64
#  6   sbytes             175341 non-null  int64
#  7   dbytes             175341 non-null  int64
#  8   rate               175341 non-null  float64
#  9   sttl               175341 non-null  int64
#  10  dttl               175341 non-null  int64
#  11  sload              175341 non-null  float64
#  12  dload              175341 non-null  float64
#  13  sinpkt             175341 non-null  float64
#  14  dinpkt             175341 non-null  float64
# ...

# %%
# box plot
for i in numerical.columns:
    plt.figure()
    sns.boxplot(numerical[i])
    plt.show()

# %%
y = df['label']
df.drop(columns=['label'], inplace=True,axis= 1)

# %%
numerical = df.select_dtypes(include = 'number')
cat = df.select_dtypes(exclude = 'number')

# %%
# robust scaler
from sklearn.preprocessing import RobustScaler
rs = RobustScaler()
df[numerical.columns] = rs.fit_transform(numerical)

# %%
df[numerical.columns].head()
# Out:
#         dur  spkts  dpkts    sbytes     dbytes      rate      sttl      dttl  \
# 0  0.179469    0.4    0.2 -0.131902   0.007260 -0.025220 -0.010417  0.892857
# 1  0.970450    1.2    3.6  0.233129  37.976407 -0.025185 -1.000000  0.884921
# 2  2.427244    0.6    1.4 -0.050613  11.816697 -0.025700 -1.000000  0.884921
# 3  2.514830    1.0    1.0  0.151840   0.549909 -0.025704 -1.000000  0.884921
# 4  0.670406    0.8    0.4  0.079755   0.094374 -0.025546  0.000000  0.884921
#
#       sload      dload  ...  trans_depth  response_body_len  ct_srv_src  \
# 0 -0.009738   0.253129  ...          0.0                0.0        -0.4
# 1 -0.009803  18.032918  ...          0.0                0.0         3.8
# 2 -0.009880   2.136200  ...          0.0                0.0         0.2
# 3 -0.009867   0.068652  ...          0.0                0.0        -0.4
# 4 -0.009801   0.091221  ...          0.0                0.0         3.8
#
# ...

# %%
# mutual info score
from sklearn.metrics import mutual_info_score
import pandas as pd

# One-hot encode the categorical features
df_encoded = pd.get_dummies(df, columns=cat.columns, drop_first=True)

# Calculate mutual info scores for each feature
mi_scores = df_encoded.apply(lambda x: mutual_info_score(y, x))

print(mi_scores)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/cluster/_supervised.py:59: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/cluster/_supervised.py:59: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/cluster/_supervised.py:59: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/cluster/_supervised.py:59: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# ...

# %%
# split into train and valid
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(df_encoded, y, test_size=0.2, random_state=42)

# %%
# simple models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report,auc,roc_auc_score,roc_curve

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Naive Bayes': GaussianNB(),
    'AdaBoost': AdaBoostClassifier(),
    'XGBoost': XGBClassifier()
}

# %%
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_valid)
    class_report = classification_report(y_valid, y_pred)
    print(f"{name} Classification Report:\n{class_report}\n")
    print(f"{name} Confusion Matrix:\n{confusion_matrix(y_valid, y_pred)}\n")
    roc_auc = roc_auc_score(y_valid, y_pred)
    print(f"{name} ROC AUC Score: {roc_auc}\n")
    results[name] = {
        'accuracy': accuracy_score(y_valid, y_pred),
        'precision': precision_score(y_valid, y_pred),
        'recall': recall_score(y_valid, y_pred),
        'f1_score': f1_score(y_valid, y_pred),
        'roc_auc': roc_auc,
    }
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.70      0.78     11169
#            1       0.87      0.96      0.91     23900
#
#     accuracy                           0.88     35069
#    macro avg       0.88      0.83      0.85     35069
# weighted avg       0.88      0.88      0.87     35069
#
#
# Logistic Regression Confusion Matrix:
# [[ 7778  3391]
#  [  946 22954]]
#
# ...

# %%
# get y_proba
for name, model in models.items():
    y_prob = model.predict_proba(X_valid)[:, 1]
    results[name]['y_prob'] = y_prob

# %%
plt.figure(figsize=(10, 7))
for name, res in results.items():
    fpr, tpr, _ = roc_curve(y_valid, res['y_prob'])
    plt.plot(fpr, tpr, label=f"{name} (AUC = {res['roc_auc']:.2f})")

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves")
plt.legend()
plt.grid()
plt.show()

# %%
# feature importance for xgboost
importances = models['XGBoost'].feature_importances_
indices = np.argsort(importances)[::-1]
imp_df = pd.DataFrame({'Feature': df_encoded.columns[indices], 'Importance': importances[indices]})
imp_df.head(20)
# Out:
#              Feature  Importance
# 0               sttl    0.820340
# 1               swin    0.023562
# 2        service_dns    0.013885
# 3         proto_unas    0.012215
# 4              smean    0.010139
# 5       ct_state_ttl    0.009826
# 6         ct_srv_src    0.009419
# 7             sbytes    0.009401
# 8       service_http    0.009047
# 9          proto_udp    0.008530
# 10       trans_depth    0.008090
# 11  ct_dst_sport_ltm    0.007271
# 12             dpkts    0.005115
# 13            dbytes    0.005113
# 14             dmean    0.004643
# 15            synack    0.004492
# 16         state_INT    0.003295
# 17        proto_icmp    0.002901
# 18            sinpkt    0.002593
# 19            tcprtt    0.002260

# %%
# plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=imp_df.head(10))
plt.title('Top 10 Feature Importances')
plt.show()

# %%
test = pd.read_csv('UNSW_NB15_testing-set.csv')

# %%
test = test.drop(['attack_cat'],axis = 1)
test = test.drop(['id'],axis = 1)
test.drop(columns=todrop, inplace=True)

# %%
test.dropna(inplace=True)

# %%
test['label'].value_counts()
# Out:
# label
# 1    45332
# 0    37000
# Name: count, dtype: int64

# %%
x_test = test.drop(['label'],axis = 1)
y_test = test['label']

# %%
num_test = x_test.select_dtypes(include = 'number')
cat_test = x_test.select_dtypes(exclude = 'number')

# %%
# scale
x_test[num_test.columns] = rs.transform(num_test)

# %%
# encode
x_test = pd.get_dummies(x_test, columns=cat_test.columns, drop_first=True)

# %%
# try xgboost on training data
# Align columns - add missing columns from training and fill with 0
x_test = x_test.reindex(columns=df_encoded.columns, fill_value=0)

y_pred = models['XGBoost'].predict(x_test)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(roc_auc_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.73      0.83     37000
#            1       0.82      0.97      0.89     45332
#
#     accuracy                           0.86     82332
#    macro avg       0.88      0.85      0.86     82332
# weighted avg       0.88      0.86      0.86     82332
#
# [[27181  9819]
#  [ 1407 43925]]
# 0.8517919720214348

# %%
# try all models on testing
test_results = {}
for name, model in models.items():
    y_pred = model.predict(x_test)
    print(f"{name} Classification Report:\n{classification_report(y_test, y_pred)}\n")
    print(f"{name} Confusion Matrix:\n{confusion_matrix(y_test, y_pred)}\n")
    print(f"{name} ROC AUC Score: {roc_auc_score(y_test, y_pred)}\n")
    test_results[name] = {
        'accuracy': accuracy_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred),
        'recall': recall_score(y_test, y_pred),
        'f1_score': f1_score(y_test, y_pred),
        'roc_auc': roc_auc_score(y_test, y_pred),
        'y_prob': model.predict_proba(x_test)[:, 1]
    }
# Out:
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.45      0.60     37000
#            1       0.68      0.95      0.79     45332
#
#     accuracy                           0.73     82332
#    macro avg       0.78      0.70      0.70     82332
# weighted avg       0.77      0.73      0.71     82332
#
#
# Logistic Regression Confusion Matrix:
# [[16772 20228]
#  [ 2234 43098]]
#
# Logistic Regression ROC AUC Score: 0.7020082180477486
#
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.75      0.83     37000
#            1       0.82      0.95      0.88     45332
#
#     accuracy                           0.86     82332
#    macro avg       0.87      0.85      0.86     82332
# weighted avg       0.87      0.86      0.86     82332
#
#
# Decision Tree Confusion Matrix:
# [[27775  9225]
#  [ 2299 43033]]
#
# ...

# %%
plt.figure(figsize=(10, 7))
for name, res in test_results.items():
    fpr, tpr, _ = roc_curve(y_test, res['y_prob'])
    plt.plot(fpr, tpr, label=f"{name} (AUC = {res['roc_auc']:.2f})")

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves")
plt.legend()
plt.grid()
plt.show()

# %%
# feature importance
importances = models['XGBoost'].feature_importances_
indices = np.argsort(importances)[::-1]
imp_df = pd.DataFrame({'Feature': df_encoded.columns[indices], 'Importance': importances[indices]})
imp_df
# Out:
#              Feature  Importance
# 0               sttl    0.820340
# 1               swin    0.023562
# 2        service_dns    0.013885
# 3         proto_unas    0.012215
# 4              smean    0.010139
# ..               ...         ...
# 179         proto_fc    0.000000
# 180       proto_fire    0.000000
# 181        proto_ggp    0.000000
# 182     is_ftp_login    0.000000
# 183  is_sm_ips_ports    0.000000
#
# [184 rows x 2 columns]

# %%
# select features bigger than threshold
def select_features(model,x_train, x_valid, x_test, y_train, threshold):
    importances = model.feature_importances_
    indices = np.where(importances > threshold)
    selected_features = x_train.columns[indices]
    x_train_selected = x_train[selected_features]
    x_valid_selected = x_valid[selected_features]
    x_test_selected = x_test[selected_features]
    return x_train_selected, x_valid_selected, x_test_selected

# %%
def train_and_evaluate_model(model, x_train, y_train, x_valid, y_valid):
    model.fit(x_train, y_train)
    y_pred_valid = model.predict(x_valid)
    print(classification_report(y_valid, y_pred_valid))
    print(confusion_matrix(y_valid, y_pred_valid))
    print(roc_auc_score(y_valid, y_pred_valid))

# %%
# try diffrent thresholds
thresholds = [0.001,0.01,0.1,0.2]
for threshold in thresholds:
    x_train_selected, x_valid_selected, x_test_selected = select_features(X_train, X_valid, x_test, y_train, threshold)
    print(f"Threshold: {threshold}")
    xgb = XGBClassifier()
    train_and_evaluate_model(xgb, x_train_selected, y_train, x_valid_selected, y_valid, x_test_selected, y_test)
# Out:
# Threshold: 0.001
# Validation Data:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93     11169
#            1       0.96      0.98      0.97     23900
#
#     accuracy                           0.96     35069
#    macro avg       0.95      0.94      0.95     35069
# weighted avg       0.96      0.96      0.96     35069
#
# [[10131  1038]
#  [  526 23374]]
# 0.9425279136701967
# Threshold: 0.01
# Validation Data:
#               precision    recall  f1-score   support
#
#            0       0.97      0.83      0.89     11169
#            1       0.92      0.99      0.95     23900
#
#     accuracy                           0.94     35069
#    macro avg       0.94      0.91      0.92     35069
# weighted avg       0.94      0.94      0.93     35069
#
# [[ 9252  1917]
#  [  335 23565]]
# 0.9071737429998078
# Threshold: 0.1
# Validation Data:
#               precision    recall  f1-score   support
#
# ...

# %%
# features that have 0 importance
importances = models['XGBoost'].feature_importances_
indices = np.where(importances == 0)
zero_importance_features = df_encoded.columns[indices]
print(zero_importance_features)
# Out:
# Index(['is_ftp_login', 'is_sm_ips_ports', 'proto_a/n', 'proto_aes-sp3-d',
#        'proto_any', 'proto_argus', 'proto_aris', 'proto_arp', 'proto_ax.25',
#        'proto_bbn-rcc',
#        ...
#        'service_radius', 'service_snmp', 'service_ssh', 'service_ssl',
#        'state_ECO', 'state_FIN', 'state_PAR', 'state_REQ', 'state_URN',
#        'state_no'],
#       dtype='object', length=138)

# %%
print(len(zero_importance_features))
# Out:
# 138

# %%
print(len(zero_importance_features) - len(df_encoded.columns))
# Out:
# -46

# %%
# try without 0
x_train_selected, x_valid_selected, x_test_selected = select_features(X_train, X_valid, x_test, y_train, 0)
xgb = XGBClassifier()
train_and_evaluate_model(xgb, x_train_selected, y_train, x_valid_selected, y_valid)
# Out:
# Validation Data:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93     11169
#            1       0.96      0.98      0.97     23900
#
#     accuracy                           0.96     35069
#    macro avg       0.95      0.94      0.95     35069
# weighted avg       0.96      0.96      0.96     35069
#
# [[10161  1008]
#  [  521 23379]]
# 0.9439755191352633

# %%
train_and_evaluate_model(xgb, X_train, y_train, x_test, y_test)
# Out:
# Validation Data:
#               precision    recall  f1-score   support
#
#            0       0.95      0.73      0.83     37000
#            1       0.82      0.97      0.89     45332
#
#     accuracy                           0.86     82332
#    macro avg       0.88      0.85      0.86     82332
# weighted avg       0.88      0.86      0.86     82332
#
# [[27118  9882]
#  [ 1371 43961]]
# 0.8513376911721569

# %%
original_df_train = pd.read_csv('UNSW_NB15_training-set.csv')
original_dt_test = pd.read_csv('UNSW_NB15_testing-set.csv')

# %%
# drop id
original_df_train = original_df_train.drop(['id'],axis = 1)
original_dt_test = original_dt_test.drop(['id'],axis = 1)

# %%
df_encoded_org = pd.get_dummies(original_df_train, columns=cat.columns, drop_first=True)
x_test = pd.get_dummies(original_dt_test, columns=cat.columns, drop_first=True)
x_train_org = df_encoded_org.drop(['label'],axis = 1)
y_train_org = df_encoded_org['label']
x_test_org = x_test.drop(['label'],axis = 1)
y_test_org = x_test['label']

# scale
x_train_org[num_test.columns] = rs.fit_transform(x_train_org[num_test.columns])
x_test_org[num_test.columns] = rs.transform(x_test_org[num_test.columns])

# %%
# split to valid
X_train_org, X_valid_org, y_train_org, y_valid_org = train_test_split(x_train_org, y_train_org, test_size=0.2, random_state=42)

# %%
# try xbg
train_and_evaluate_model(xgb, X_train_org, y_train_org, X_valid_org, y_valid_org)
# Out:
# Validation Data:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93     11169
#            1       0.96      0.98      0.97     23900
#
#     accuracy                           0.96     35069
#    macro avg       0.96      0.95      0.95     35069
# weighted avg       0.96      0.96      0.96     35069
#
# [[10222   947]
#  [  521 23379]]
# 0.94670629180963

# %%
# try on test
x_test_org_aligned = x_test_org.reindex(columns=X_train_org.columns, fill_value=0)
xgb = XGBClassifier()
train_and_evaluate_model(xgb, X_train_org, y_train_org, x_test_org_aligned, y_test_org)
# Out:
# Validation Data:
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84     37000
#            1       0.82      0.98      0.89     45332
#
#     accuracy                           0.87     82332
#    macro avg       0.89      0.86      0.86     82332
# weighted avg       0.89      0.87      0.87     82332
#
# [[27257  9743]
#  [  918 44414]]
# 0.8582125400349612

# %%
# exclude 0 importance
x_train_selected, x_valid_selected, x_test_selected = select_features(xgb,X_train_org, X_valid_org, x_test_org_aligned, y_train_org, 0)
train_and_evaluate_model(xgb, x_train_selected, y_train_org, x_valid_selected, y_valid_org)
# Out:
# Validation Data:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93     11169
#            1       0.96      0.98      0.97     23900
#
#     accuracy                           0.96     35069
#    macro avg       0.96      0.95      0.95     35069
# weighted avg       0.96      0.96      0.96     35069
#
# [[10222   947]
#  [  521 23379]]
# 0.94670629180963

# %%
train_and_evaluate_model(xgb, x_train_selected, y_train_org, x_test_selected, y_test_org)
# Out:
# Validation Data:
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84     37000
#            1       0.82      0.98      0.89     45332
#
#     accuracy                           0.87     82332
#    macro avg       0.89      0.86      0.86     82332
# weighted avg       0.89      0.87      0.87     82332
#
# [[27257  9743]
#  [  918 44414]]
# 0.8582125400349612

# %%
# try label encoder on original data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_label_encoded = original_df_train.copy()
df_encoded_test = original_dt_test.copy()
num_test = df_label_encoded.select_dtypes(include = 'number')
cat = df_label_encoded.select_dtypes(exclude = 'number')
df_label_encoded[cat.columns] = df_label_encoded[cat.columns].apply(lambda col: le.fit_transform(col))
df_encoded_test[cat.columns] = df_encoded_test[cat.columns].apply(lambda col: le.fit_transform(col))
x_label_encoded = df_label_encoded.drop(['label'],axis = 1)
y_label_encoded = df_label_encoded['label']
x_test_label_encoded = df_encoded_test.drop(['label'],axis = 1)
y_test_label_encoded = df_encoded_test['label']

# %%
num_test = x_label_encoded.select_dtypes(include = 'number')
cat = x_label_encoded.select_dtypes(exclude = 'number')

# %%
# scale
x_label_encoded[num_test.columns] = rs.fit_transform(x_label_encoded[num_test.columns])
x_test_label_encoded[num_test.columns] = rs.transform(x_test_label_encoded[num_test.columns])

# %%
X_train_label, X_valid_label, y_train_label, y_valid_label = train_test_split(x_label_encoded, y_label_encoded, test_size=0.2, random_state=42)

# %%
# try xgboost again
train_and_evaluate_model(xgb, X_train_label, y_train_label, X_valid_label, y_valid_label)
# Out:
# Validation Data:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93     11169
#            1       0.96      0.98      0.97     23900
#
#     accuracy                           0.96     35069
#    macro avg       0.96      0.95      0.95     35069
# weighted avg       0.96      0.96      0.96     35069
#
# [[10199   970]
#  [  537 23363]]
# 0.9453419281776255

# %%
train_and_evaluate_model(xgb, X_train_label, y_train_label, x_test_label_encoded, y_test_label_encoded)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74     37000
#            1       0.75      1.00      0.86     45332
#
#     accuracy                           0.81     82332
#    macro avg       0.87      0.79      0.80     82332
# weighted avg       0.86      0.81      0.80     82332
#
# [[21821 15179]
#  [  143 45189]]
# 0.7933011261062528

# %%
cat = original_df_train.select_dtypes(exclude = 'number')

# %%
# try one hot encode with standard scaler
df_one_hot_encoded = pd.get_dummies(original_df_train, columns=cat.columns)
df_encoded_test_one_hot = pd.get_dummies(original_dt_test, columns=cat.columns)
x_one_hot_encoded = df_one_hot_encoded.drop(['label'],axis = 1)
y_one_hot_encoded = df_one_hot_encoded['label']
x_test_one_hot_encoded = df_encoded_test_one_hot.drop(['label'],axis = 1)
y_test_one_hot_encoded = df_encoded_test_one_hot['label']

# %%
x_test_one_hot_encoded.columns
# Out:
# Index(['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl',
#        'sload', 'dload',
#        ...
#        'service_snmp', 'service_ssh', 'service_ssl', 'state_ACC', 'state_CLO',
#        'state_CON', 'state_FIN', 'state_INT', 'state_REQ', 'state_RST'],
#       dtype='object', length=190)

# %%
# Redefine numerical and categorical based on the one-hot encoded training data
numerical_cols_one_hot = x_one_hot_encoded.select_dtypes(include=np.number).columns

# %%
# standard scaler
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# Ensure test set has the same columns as the training set after one-hot encoding
x_test_one_hot_encoded = x_test_one_hot_encoded.reindex(columns=x_one_hot_encoded.columns, fill_value=0)


# Apply StandardScaler to numerical columns in both training and test sets
x_one_hot_encoded[numerical_cols_one_hot] = ss.fit_transform(x_one_hot_encoded[numerical_cols_one_hot])
x_test_one_hot_encoded[numerical_cols_one_hot] = ss.transform(x_test_one_hot_encoded[numerical_cols_one_hot])

# %%
# split valid
X_train_one_hot, X_valid_one_hot, y_train_one_hot, y_valid_one_hot = train_test_split(x_one_hot_encoded, y_one_hot_encoded, test_size=0.2, random_state=42)

# %%
train_and_evaluate_model(xgb, X_train_one_hot, y_train_one_hot, X_valid_one_hot, y_valid_one_hot)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93     11169
#            1       0.96      0.98      0.97     23900
#
#     accuracy                           0.96     35069
#    macro avg       0.96      0.95      0.95     35069
# weighted avg       0.96      0.96      0.96     35069
#
# [[10209   960]
#  [  507 23393]]
# 0.9464172108919224

# %%
train_and_evaluate_model(xgb, X_train_one_hot, y_train_one_hot, x_test_one_hot_encoded, y_test_one_hot_encoded)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84     37000
#            1       0.82      0.98      0.89     45332
#
#     accuracy                           0.87     82332
#    macro avg       0.90      0.86      0.87     82332
# weighted avg       0.89      0.87      0.87     82332
#
# [[27243  9757]
#  [  831 44501]]
# 0.85898293789245

# %%
xgb = XGBClassifier(learning_rate=0.1, max_depth=7, n_estimators=300)

# %%
train_and_evaluate_model(xgb, x_train_selected, y_train_org, x_valid_selected, y_valid_org)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94     11169
#            1       0.96      0.98      0.97     23900
#
#     accuracy                           0.96     35069
#    macro avg       0.96      0.95      0.95     35069
# weighted avg       0.96      0.96      0.96     35069
#
# [[10234   935]
#  [  486 23414]]
# 0.9479757105646944

# %%
train_and_evaluate_model(xgb, x_train_selected, y_train_org, x_test_selected, y_test_org)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84     37000
#            1       0.82      0.98      0.89     45332
#
#     accuracy                           0.87     82332
#    macro avg       0.90      0.86      0.87     82332
# weighted avg       0.89      0.87      0.87     82332
#
# [[27275  9725]
#  [  786 44546]]
# 0.8599117084524744

# %%
# random balanced RF
from imblearn.ensemble import BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier()
train_and_evaluate_model(brf, x_train_selected, y_train_org, x_valid_selected, y_valid_org)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93     11169
#            1       0.97      0.96      0.97     23900
#
#     accuracy                           0.96     35069
#    macro avg       0.95      0.95      0.95     35069
# weighted avg       0.96      0.96      0.96     35069
#
# [[10564   605]
#  [  879 23021]]
# 0.9545269857431902

# %%
train_and_evaluate_model(brf, x_train_selected, y_train_org, x_test_selected, y_test_org)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.80      0.88     37000
#            1       0.86      0.97      0.91     45332
#
#     accuracy                           0.90     82332
#    macro avg       0.91      0.89      0.89     82332
# weighted avg       0.91      0.90      0.90     82332
#
# [[29783  7217]
#  [ 1174 44158]]
# 0.8895240627109063
